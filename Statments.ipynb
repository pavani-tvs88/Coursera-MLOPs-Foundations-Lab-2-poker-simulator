# %% [markdown]
# <a href="https://colab.research.google.com/github/pavani-tvs88/Coursera-MLOPs-Foundations-Lab-2-poker-simulator/blob/main/Statments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learning Statements

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Variables

# %%
variable = 1

# %%
x=1
y=2
x+y
# Out:
# 3

# %% [markdown]
# ### Data Structures

# %%
my_list = [1,2,3]
# Out:
# 2

# %%
my_list[0]
# Out:
# 1

# %%
my_list[1]
# Out:
# 2
